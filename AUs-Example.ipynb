# %% [markdown]
# # AUs (Action Units) refined command driven 3D face animation generation

# %% [markdown]
# ## Action Units Defination

# %% [markdown]
# |  AU  |     Defination    |  AU  |      Defination      |
# |:----:|:-----------------:|:----:|:--------------------:|
# | AU01 | Inner brow raiser | AU14 |        Dimpler       |
# | AU02 | Outer brow raiser | AU15 | Lip corner depressor |
# | AU04 |    Brow Lowerer   | AU17 |      Chin Raiser     |
# | AU05 |  Upper lid raiser | AU20 |     Lip Stretcher    |
# | AU06 |    Cheek raiser   | AU23 |     Lip tightener    |
# | AU07 |   Lid tightener   | AU25 |       Lips part      |
# | AU09 |   Nose wrinkler   | AU26 |       Jaw drop       |
# | AU10 |  Upper lip raiser | AU45 |         Blink        |
# | AU12 | Lip corner puller |      |                      |

# %% [markdown]
# ## Image demo

# %%
from IPython import display
display.Image(filename='TestSamples/real/me.jpg')

# %% [markdown]
# ## Set running settings

# %% [markdown]
# **emotion_driven_function** ：Tar_AU_Parameter_driver<br>
# **Tar_AU_Parameter**：
#
# |  AU  |     Defination    | Intensity |  AU  |      Defination      | Intensity |
# |:----:|:-----------------:|:---------:|:----:|:--------------------:|-----------|
# | AU01 | Inner brow raiser |    0.8   | AU14 |        Dimpler       |    0.0    |
# | AU02 | Outer brow raiser |    0.8    | AU15 | Lip corner depressor |    0.0    |
# | AU04 |    Brow Lowerer   |    0.0    | AU17 |      Chin Raiser     |    0.0    |
# | AU05 |  Upper lid raiser |   0.0   | AU20 |     Lip Stretcher    |    0.0    |
# | AU06 |    Cheek raiser   |    0.0   | AU23 |     Lip tightener    |    0.0    |
# | AU07 |   Lid tightener   |   0.0   | AU25 |       Lips part      | 0.0     |
# | AU09 |   Nose wrinkler   |    0.0    | AU26 |       Jaw drop       | 0.6     |
# | AU10 |  Upper lip raiser |    0.0    | AU45 |         Blink        |    0.0    |
# | AU12 | Lip corner puller |    0.0    |      |                      |           |
#
# **image_path**：TestSamples/real/me.jpg <br>

# %%
# !python demos/demo_transfer.py --emotion_driven_function Tar_AU_Parameter_driver --image_path 'TestSamples/real/me.jpg' --Tar_AU_Parameter 0.8000 0.8000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.6000 0.0000
# Out:
# 2025-04-13 13:47:58.298865: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-13 13:47:58.301489: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-13 13:47:58.355687: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-13 13:47:58.356216: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
display.Image(filename='./results/me_edit_AU.gif')
